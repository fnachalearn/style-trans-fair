# %%
# RIGHT NOW, PRIVATE REPOS DOES NOT SUPPORT IMAGES IN MARKDOWN
from IPython.display import Image
Image(filename="images/dark_logo.jpg", width=200)
# WE CHANGED IT IN THE STARTING KIT UPLOADED ON CODABENCH

# %% [markdown]
# <div style="background:#FFFFFF">
# <!-- <img src="../images/dataset-cover.jpg" width=150 ALIGN="left" style='margin-right:10px; border-style: solid; border-width: 2px;' alt='logo'> -->
# <h1>Starting Kit - Style-Trans-Fair </h1>
# <p>
# This starting kit will guide you step by step and will walk you through the data statistics and<br>
# examples. This will give you a clear idea of what this challenge is about and how you can<br>
# proceed further to solve the challenge.
# </p>
#
# <br><br>
# <hr style='background-color: #D3D3D3; height: 1px; border: 0;'>
# <p>
# This code was tested with Python 3.8.5 |Anaconda custom (64-bit)| (default, Dec 23 2020, 21:19:02) (https://anaconda.org/)<br>
# </p>
# <hr style='background-color: #D3D3D3; height: 1px; border: 0;'>
#
# <p>
# ALL INFORMATION, SOFTWARE, DOCUMENTATION, AND DATA ARE PROVIDED "AS-IS". The CHALEARN, AND/OR OTHER ORGANIZERS OR CODE AUTHORS DISCLAIM ANY EXPRESSED OR IMPLIED WARRANTIES, INCLUDING, BUT NOT LIMITED TO, THE IMPLIED WARRANTIES OF MERCHANTABILITY AND FITNESS FOR ANY PARTICULAR PURPOSE, AND THE WARRANTY OF NON-INFRIGEMENT OF ANY THIRD PARTY'S INTELLECTUAL PROPERTY RIGHTS. IN NO EVENT SHALL AUTHORS AND ORGANIZERS BE LIABLE FOR ANY SPECIAL,
# INDIRECT OR CONSEQUENTIAL DAMAGES OR ANY DAMAGES WHATSOEVER ARISING OUT OF OR IN CONNECTION WITH THE USE OR PERFORMANCE OF SOFTWARE, DOCUMENTS, MATERIALS, PUBLICATIONS, OR INFORMATION MADE AVAILABLE FOR THE CHALLENGE.
# </p>
#
# <hr style='background-color: #D3D3D3; height: 1px; border: 0;'>
#     <p>
# This challenge was organized by <b>Team Fairness National Assembly</b> of <b><a style='color:#4D6605;' href='http://www.chalearn.org/'>ChaLearn</a></b>  at <b><a style='color: #62023C;' href='https://www.universite-paris-saclay.fr/'>Université Paris Saclay</a></b>
# </p>
# </div>
#
# <hr style='background-color: #D3D3D3; height: 1px; border: 0;'>

# %% [markdown]
# ***
# # Introduction
#
# This challenge uses a Dataset from ***Meta Album***. There are 5 tasks in the Development phase and 5 tasks in the Final Phase.
# Each task in the dataset consists of **360** images splited into 9 groups:
# <!--
# <p>
# <img src="../images/task_distribution.png">
# </p> -->

# %%
# RIGHT NOW, PRIVATE REPOS DOES NOT SUPPORT IMAGES IN MARKDOWN
Image(filename="images/task_distribution.png") 
# WE CHANGED IT IN THE STARTING KIT UPLOADED ON CODABENCH

# %% [markdown]
# where the training set is biased in Style, and the test set is balanced.
#
# The sample dataset in this starting kit conists of **360** images of the Insect classification task.
#
# This challenge is about creating a Machine Learning model and train it with the data provided to classify the images into the mentioned 3 Classes without being biased towards Styles.
#
#
# **References and credits:**
#  - Meta Album (https://meta-album.github.io/)
#  - Université Paris Saclay (https://www.universite-paris-saclay.fr/)
#  - ChaLearn (http://www.chalearn.org/)
# ***

# %% [markdown]
# ### Install required packages

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: appnope==0.1.2 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: asttokens==2.0.5 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 2)) (2.0.5)
# Requirement already satisfied: backcall==0.2.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: Bottleneck==1.3.5 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 4)) (1.3.5)
# Requirement already satisfied: certifi==2022.12.7 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 5)) (2022.12.7)
# Requirement already satisfied: charset-normalizer==3.0.1 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 6)) (3.0.1)
# Requirement already satisfied: cloudpickle==2.0.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 7)) (2.0.0)
# Requirement already satisfied: comm==0.1.2 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 8)) (0.1.2)
# Requirement already satisfied: contourpy==1.0.5 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 9)) (1.0.5)
# Requirement already satisfied: cycler==0.11.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 10)) (0.11.0)
# Requirement already satisfied: cytoolz==0.12.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 11)) (0.12.0)
# Requirement already satisfied: dask==2022.7.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 12)) (2022.7.0)
# Requirement already satisfied: debugpy==1.5.1 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 13)) (1.5.1)
# Requirement already satisfied: decorator==5.1.1 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 14)) (5.1.1)
# Requirement already satisfied: entrypoints==0.4 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 15)) (0.4)
# Requirement already satisfied: executing==0.8.3 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 16)) (0.8.3)
# Requirement already satisfied: fonttools==4.25.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 17)) (4.25.0)
# Requirement already satisfied: fsspec==2022.11.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 18)) (2022.11.0)
# Requirement already satisfied: idna==3.4 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 19)) (3.4)
# Requirement already satisfied: imageio==2.19.3 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 20)) (2.19.3)
# Requirement already satisfied: ipykernel==6.19.2 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 21)) (6.19.2)
# Requirement already satisfied: ipython==8.7.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 22)) (8.7.0)
# Requirement already satisfied: jedi==0.18.1 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 23)) (0.18.1)
# Requirement already satisfied: joblib==1.1.1 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 24)) (1.1.1)
# Requirement already satisfied: jupyter_client==7.4.8 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 25)) (7.4.8)
# Requirement already satisfied: jupyter_core==5.1.1 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 26)) (5.1.1)
# Requirement already satisfied: kiwisolver==1.4.4 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 27)) (1.4.4)
# Requirement already satisfied: locket==1.0.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 28)) (1.0.0)
# Requirement already satisfied: matplotlib==3.6.2 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 29)) (3.6.2)
# Requirement already satisfied: matplotlib-inline==0.1.6 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 30)) (0.1.6)
# Requirement already satisfied: munkres==1.1.4 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 31)) (1.1.4)
# Requirement already satisfied: nest-asyncio==1.5.6 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 32)) (1.5.6)
# Requirement already satisfied: networkx==2.8.4 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 33)) (2.8.4)
# Requirement already satisfied: numexpr==2.8.4 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 34)) (2.8.4)
# Requirement already satisfied: numpy==1.23.5 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 35)) (1.23.5)
# Requirement already satisfied: opencv-python==4.7.0.68 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 36)) (4.7.0.68)
# Requirement already satisfied: packaging==22.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 37)) (22.0)
# Requirement already satisfied: pandas==1.5.2 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 38)) (1.5.2)
# Requirement already satisfied: parso==0.8.3 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 39)) (0.8.3)
# Requirement already satisfied: partd==1.2.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 40)) (1.2.0)
# Requirement already satisfied: pexpect==4.8.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 41)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 42)) (0.7.5)
# Requirement already satisfied: Pillow==9.3.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 43)) (9.3.0)
# Requirement already satisfied: pip==22.3.1 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 44)) (22.3.1)
# Requirement already satisfied: platformdirs==2.5.2 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 45)) (2.5.2)
# Requirement already satisfied: prompt-toolkit==3.0.36 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 46)) (3.0.36)
# Requirement already satisfied: psutil==5.9.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 47)) (5.9.0)
# Requirement already satisfied: ptyprocess==0.7.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 48)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 49)) (0.2.2)
# Requirement already satisfied: Pygments==2.11.2 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 50)) (2.11.2)
# Requirement already satisfied: pyparsing==3.0.9 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 51)) (3.0.9)
# Requirement already satisfied: python-dateutil==2.8.2 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 52)) (2.8.2)
# Requirement already satisfied: pytz==2022.7 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 53)) (2022.7)
# Requirement already satisfied: PyWavelets==1.4.1 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 54)) (1.4.1)
# Requirement already satisfied: PyYAML==6.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 55)) (6.0)
# Requirement already satisfied: pyzmq==23.2.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 56)) (23.2.0)
# Requirement already satisfied: scikit-image==0.19.3 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 57)) (0.19.3)
# Requirement already satisfied: scikit-learn==1.1.3 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 58)) (1.1.3)
# Requirement already satisfied: scipy==1.9.3 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 59)) (1.9.3)
# Requirement already satisfied: seaborn==0.12.2 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 60)) (0.12.2)
# Requirement already satisfied: setuptools==65.6.3 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 61)) (65.6.3)
# Requirement already satisfied: six==1.16.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 62)) (1.16.0)
# Requirement already satisfied: stack-data==0.2.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 63)) (0.2.0)
# Requirement already satisfied: threadpoolctl==2.2.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 64)) (2.2.0)
# Requirement already satisfied: tifffile==2021.7.2 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 65)) (2021.7.2)
# Requirement already satisfied: toolz==0.12.0 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 66)) (0.12.0)
# Requirement already satisfied: tornado==6.2 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 67)) (6.2)
# Requirement already satisfied: traitlets==5.7.1 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 68)) (5.7.1)
# Requirement already satisfied: urllib3==1.26.14 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 69)) (1.26.14)
# Requirement already satisfied: wcwidth==0.2.5 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 70)) (0.2.5)
# Requirement already satisfied: wheel==0.37.1 in c:\users\quentin\miniconda3\lib\site-packages (from -r requirements.txt (line 71)) (0.37.1)
# Requirement already satisfied: colorama in c:\users\quentin\miniconda3\lib\site-packages (from ipython==8.7.0->-r requirements.txt (line 22)) (0.4.5)
# Requirement already satisfied: pywin32>=1.0 in c:\users\quentin\miniconda3\lib\site-packages (from jupyter_core==5.1.1->-r requirements.txt (line 26)) (305.1)

# %% [markdown]
# ### Imports

# %%
# import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Image
from PIL import Image
from sklearn.decomposition import PCA
import os

# %%
model_dir = 'sample_code_submission/' # Change the model to a better one once you have one!
result_dir = 'sample_result_submission/' 
problem_dir = 'ingestion_program/'  
score_dir = 'scoring_program/'
from sys import path; path.append(model_dir); path.append(problem_dir); path.append(score_dir); 
# %matplotlib inline
# Uncomment the next lines to auto-reload libraries (this causes some problem with pickles in Python 3)
# %load_ext autoreload
# %autoreload 2
import seaborn as sns; sns.set()
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# %reload_ext autoreload

# %% [markdown]
# ***
# # Step 1: Exploratory data analysis
# We provide `sample_data` with the starting kit, but to prepare your submission, you must fetch the `public_data` from the challenge website and point to it.
#
# The data used for this challenge has images resized into 512x512 pixels.

# %%
data_name = 'style_trans_fair_challenge' # DO NOT CHANGE
data_dir = 'sample_data' # Change it to point to the directory with public_data
image_dir = os.path.join(data_dir, 'stylized')

# %% [markdown]
# ### Load Data

# %%
from data_io import read_data
data, meta_data = read_data(os.path.join(data_dir, 'task1'), random_state=42)
# Out:
# ###-------------------------------------###
# ### Checking Data
# ###-------------------------------------###
#
#
# -------------------------------------
# [+] Your dataset is in perfect format
# -------------------------------------
#
#
# ###-------------------------------------###
# ### Loading Data
# ###-------------------------------------###
#
#
# -------------------------------------
# [+] Data loaded successfully
# -------------------------------------
#
#
# ###-------------------------------------###
# ### Loading Images
# ###-------------------------------------###
#
#
# -------------------------------------
# [+] Images loaded successfully
# -------------------------------------

# %% [markdown]
# ### Data Statistics

# %%
print("Categories/Classes : ", np.unique(data['train_labels']))
print("Styles : ", np.unique(data['train_styles']))
print("Train Images:", len(data['train_images']))
print("Test Images:", len(data['test_images']))
# Out:
# Categories/Classes :  ['Apoidea' 'Elateroidea' 'Tenthredinoidea']
# Styles :  ['autumn_leaves' 'number_one' 'trippy_flowers']
# Train Images: 60
# Test Images: 180

# %% [markdown]
# ## Visualization

# %%
def print_style_transfer_samples(row):
    f, ax = plt.subplots(1, 3)
    f.set_figheight(5)
    f.set_figwidth(15)
    ax[0].imshow(Image.open(os.path.join(data_dir, 'task1', 'content', row['ORIG_CATEGORY_FILE'].iloc[0])))
    ax[0].set_title('Original')
    ax[0].set_axis_off()
    ax[1].imshow(Image.open(os.path.join(data_dir, 'task1', 'styles', row['ORIG_STYLE_FILE'].iloc[0])))
    ax[1].set_title('Style')
    ax[1].set_axis_off()
    ax[2].imshow(Image.open(os.path.join(data_dir, 'task1', 'stylized', row['FILE_NAME'].iloc[0])))
    ax[2].set_title('Stylized')
    ax[2].set_axis_off()

# %%
print_style_transfer_samples(data['train_df'].sample(1))

# %% [markdown]
# ### Distribution of Classes/Labels

# %% [markdown]
# #### Train

# %%
grouped = data['train_df'].groupby(["CATEGORY", "STYLE"]).size().reset_index(name="COUNT")
grouped
# Out:
#           CATEGORY           STYLE  COUNT
# 0          Apoidea   autumn_leaves     12
# 1          Apoidea      number_one      4
# 2          Apoidea  trippy_flowers      4
# 3      Elateroidea   autumn_leaves      4
# 4      Elateroidea      number_one     12
# 5      Elateroidea  trippy_flowers      4
# 6  Tenthredinoidea   autumn_leaves      4
# 7  Tenthredinoidea      number_one      4
# 8  Tenthredinoidea  trippy_flowers     12

# %%
# Create the heatmap visualization for category and style
sns.heatmap(grouped.pivot("CATEGORY", "STYLE", "COUNT"), cmap="crest", annot=True, linewidths=1, linecolor='black')
plt.title('Heatmap visualization for category and style')
plt.xticks(rotation=45)
# Show the plot
plt.show()

# %% [markdown]
# #### Test

# %%
grouped = data['test_df'].groupby(["CATEGORY", "STYLE"]).size().reset_index(name="COUNT")
grouped
# Out:
#           CATEGORY           STYLE  COUNT
# 0          Apoidea   autumn_leaves     20
# 1          Apoidea      number_one     20
# 2          Apoidea  trippy_flowers     20
# 3      Elateroidea   autumn_leaves     20
# 4      Elateroidea      number_one     20
# 5      Elateroidea  trippy_flowers     20
# 6  Tenthredinoidea   autumn_leaves     20
# 7  Tenthredinoidea      number_one     20
# 8  Tenthredinoidea  trippy_flowers     20

# %%
# Create the heatmap visualization for category and style
sns.heatmap(grouped.pivot("CATEGORY", "STYLE", "COUNT"), cmap="crest", annot=True, linewidths=1, linecolor='black')
plt.title('Heatmap visualization for category and style')
plt.xticks(rotation=45)
# Show the plot
plt.show()

# %% [markdown]
# ### Further visualization

# %% [markdown]
# For further exploratory data analysis, we analyze the RGB color model and plot the graph. We get the mean for each channel of each image, and save it in the columns of a dataframe.

# %%
rgb = pd.DataFrame(
    np.zeros((len(data['train_df']), 5)), columns=list("RGB") + ["category", "style"]
)
for i in range(len(data['train_labels'])):
    img = data['train_images'][i]
    rgb.iloc[i, :3] = img.mean(axis=(0,1))
    rgb.iloc[i, 3] = data['train_labels'][i]
    rgb.iloc[i, 4] = data['train_styles'][i]
rgb.head()
# Out:
#             R           G           B category          style
# 0  185.459820  123.966339   90.308178  Apoidea  autumn_leaves
# 1  198.923672  140.519848  100.388340  Apoidea  autumn_leaves
# 2  161.696911  107.406567   34.441048  Apoidea  autumn_leaves
# 3  178.202621   99.362495   25.698387  Apoidea  autumn_leaves
# 4  215.130695   89.868198   39.454258  Apoidea  autumn_leaves

# %% [markdown]
# We also normalize each color vector, so that we only care about the direction of the color vector and not about its magnitude.

# %%
pca = PCA(2)
rgb[list("rgb")] = rgb[list("RGB")] / np.sqrt(
    np.sum(np.square(rgb[list("RGB")]), axis=1).values.reshape(-1, 1)
) 

transformed_rgb = pca.fit_transform(rgb[list("rgb")]) 
rgb[list("xy")] = transformed_rgb 
red, green, blue = pca.transform(np.identity(3))
# Out:
# c:\Users\Quentin\miniconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(

# %%
plot_data = rgb
plt.figure(figsize=(10, 10))
sns.scatterplot(x="x", y="y", hue="category", data=plot_data, palette="Set1")
plt.arrow(0, 0, *blue, color="blue")
plt.arrow(0, 0, *green, color="green")
plt.arrow(0, 0, *red, color="red")
plt.title("RGB distribution")
plt.xlabel("First PC")
plt.ylabel("Second PC")
plt.legend()
plt.show()

# %% [markdown]
# Next, we analyze the brightness of the images per category. We wanted to know which category has lower/higher brightness level so instead of using a simple mean for each RGB channel, we used a weighted mean that takes into account the perceived brightness by humans:
# - Red: 21.26%
# - Green: 71.52%
# - Blue: 7.22%

# %%
BRIGHTNESS_VECTOR = np.array([0.2126, 0.7152, 0.0722])
rgb["brightness"] = (
    rgb[list("RGB")] @ BRIGHTNESS_VECTOR / 255
)
rgb.head()
# Out:
#             R           G           B category          style         r  \
# 0  185.459820  123.966339   90.308178  Apoidea  autumn_leaves  0.770621
# 1  198.923672  140.519848  100.388340  Apoidea  autumn_leaves  0.755135
# 2  161.696911  107.406567   34.441048  Apoidea  autumn_leaves  0.820171
# 3  178.202621   99.362495   25.698387  Apoidea  autumn_leaves  0.866558
# 4  215.130695   89.868198   39.454258  Apoidea  autumn_leaves  0.909791
#
#           g         b         x         y  brightness
# 0  0.515104  0.375248  0.059244  0.001530    0.527881
# 1  0.533428  0.381085  0.042809 -0.016858    0.588388
# 2  0.544795  0.174694  0.246371 -0.088609    0.445806
# 3  0.483177  0.124965  0.323887 -0.040892    0.434531
# 4  0.380054  0.166853  0.331427  0.078275    0.442585

# %% [markdown]
# Using the boxplot we could easily identify the minimum, maximum, interquartile range, median and the outliers. Here we ordered it in respect to their lower quartile (Q1) to make it more representative.

# %%
plot_data = rgb[["category", "brightness"]].copy()
order = plot_data.groupby("category")["brightness"].quantile(0.25).sort_values().index.tolist()
plt.figure(figsize=(8, 8))
sns.boxplot(y="category", x="brightness", data=plot_data, order=order, palette="Set1")
plt.title("Luminance (perceived brightness)") 
plt.show()

# %%
ax = pd.DataFrame(rgb.groupby("category")["brightness"].mean()).plot.barh()
plt.xlabel("Brightness level")
plt.title("Plot of the brightness level")
plt.show()

# %% [markdown]
# From the graph above we can conclude that the category Elateroidea has the highest value in term of brightness level

# %% [markdown]
# ***
# # Step 2: Building a predictive model

# %% [markdown]
# ## Training a predictive model
# We provide an example of predictive model in the `sample_code_submission/` directory.
# The model will perform the following steps:
# - Resize the image to (64,64,3)
# - Flatten the image to a vector of size 64\*64\*3 = 12288
# - Train a simple Support Vector Machine to classify
#
# You should change this model and use a better one to get a good score for the challenge

# %%
from data_io import write
from model import model

# %% [markdown]
# <div style="background:#FFF">
# an instance of the model (run the constructor) and attempt to reload a previously saved version from `sample_code_submission/`:
# </div>

# %%
myModel = model()
trained_model_name = model_dir + data_name
# Uncomment the next line to re-load an already trained model
#myModel = myModel.load(trained_model_name)

# %% [markdown]
# <div style="background:#FFF">
#     Train the model (unless you reloaded a trained model) and make predictions.
# </div>

# %%
X_TRAIN = data["train_images"]
STYLE_TRAIN = data["train_styles"]
Y_TRAIN = data["train_labels_num"]
X_TEST = data["test_images"]
STYLE_TEST = data["test_styles"]
Y_TEST = data["test_labels_num"]

# %%
if not(myModel.is_trained):
    myModel.fit(X_TRAIN, Y_TRAIN)                     

Y_hat_train = myModel.predict(X_TRAIN) # Optional, not really needed to test on taining examples
Y_hat_test = myModel.predict(X_TEST)
# Out:
# FIT: dim(X)= [60, 12288]
# FIT: dim(y)= [60, 1]
# PREDICT: dim(X)= [60, 12288]
# PREDICT: dim(y)= [60, 1]
# PREDICT: dim(X)= [180, 12288]
# PREDICT: dim(y)= [180, 1]

# %% [markdown]
# **Save the trained model** (will be ready to reload next time around) and save the prediction results. <br>

# %%
myModel.save(trained_model_name)

# %% [markdown]
# **IMPORTANT:** if you save the trained model, it will be bundled with your sample code submission. Therefore your model will NOT be retrained on the challenge platform. Remove the pickle from the submission if you want the model to be retrained on the platform.
#
# **REQUIRED:** Trained model is required in the submission to codabench.

# %%
result_name = result_dir + data_name
from data_io import write
write(result_name + '_train.predict', Y_hat_train)
write(result_name + '_test.predict', Y_hat_test)

# !ls $result_name*
# Out:
# 'ls' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.

# %% [markdown]
# ## Scoring the results
# ### Load the challenge metric
#
# **The metric chosen for your challenge** is identified in the "metric.txt" file found in the `scoring_program/` directory.
# <br>
# The function "get_metric" searches first for a metric having that name in my_metric.py, then in libscores.py, then in sklearn.metric.
#
# Currently, we are using geometric_mean_accuracy_metric, which is calculated by:
# - Split the data in 9 groups, where images in each group have the same style and category
# - Calculate the accuracy in each group
# - Calculate the Geometric Mean of those 9 accuracies

# %%
from libscores import get_metric
metric_name, scoring_function = get_metric()
print('Using scoring metric:', metric_name)
# Uncomment the next line to display the code of the scoring metric
??scoring_function
# Out:
# Using scoring metric: geometric_mean_accuracy_metric
# Signature: scoring_function(solution, prediction, style_solution)
# Source:
# def geometric_mean_accuracy_metric(solution, prediction, style_solution):
#     '''Worst group accuracy.
#     Works even if the target matrix has more than one column'''
#     group_accuracies = []
#     for category in np.unique(solution):
#         for style in np.unique(style_solution):
#             group_index = np.where((solution==category) & (style_solution==style))
#             group_accuracies.append(accuracy_score(solution[group_index],prediction[group_index]))
#     score = gmean(group_accuracies)
#     return score
# File:      c:\users\quentin\documents\github\style-trans-fair\scoring_program\my_metric.py
# Type:      function

# %% [markdown]
# ## Training performance

# %%
print('Training score for the', metric_name, 'metric = %5.4f' % scoring_function(Y_TRAIN, Y_hat_train, STYLE_TRAIN))
print('Ideal score for the', metric_name, 'metric = %5.4f' % scoring_function(Y_TRAIN, Y_TRAIN, STYLE_TRAIN))

print('Test score for the', metric_name, 'metric = %5.4f' % scoring_function(Y_TEST, Y_hat_test, STYLE_TEST))
# Out:
# Training score for the geometric_mean_accuracy_metric metric = 1.0000
# Ideal score for the geometric_mean_accuracy_metric metric = 1.0000
# Test score for the geometric_mean_accuracy_metric metric = 0.0000

# %% [markdown]
# You can add here other scores and result visualization.

# %% [markdown]
# ## Confusion matrix

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix = confusion_matrix(Y_TRAIN, Y_hat_train)

# %%
confusion_matrix
# Out:
# array([[20,  0,  0],
#        [ 0, 20,  0],
#        [ 0,  0, 20]], dtype=int64)

# %%
df_cm = pd.DataFrame(confusion_matrix, range(confusion_matrix.shape[0]), range(confusion_matrix.shape[1]))
sns.heatmap(df_cm, annot=True)
plt.title("Train - Confustion Matrix")
plt.show()

# %% [markdown]
# ***
# # Step 3: Making a submission
#
# ## Unit testing
#
# It is <b><span style="color:red">important that you test your submission files before submitting them</span></b>. All you have to do to make a submission is modify the file <code>model.py</code> in the <code>sample_code_submission/</code> directory, then run this test to make sure everything works fine. This is the actual program that will be run on the server to test your submission.
# <br>
# Keep the sample code simple.<br>
#
# <code>python3</code> is required for this step

# %%
# !source activate python3; 
# !python3 $problem_dir/ingestion.py $data_dir $result_dir $problem_dir $model_dir
# Out:
# Python est introuvable. Ex�cutez sans argument pour proc�der � l

# %% [markdown]
# ### Test scoring program

# %%
scoring_output_dir = 'scoring_output'
# !source activate deeplearning;
# !py $score_dir/score.py $data_dir $result_dir $scoring_output_dir
# Out:
# ###-------------------------------------###
# ### Using metric :  geometric_mean_accuracy_metric
# ###-------------------------------------###
#
#
# ###-------------------------------------###
# ### Train solutions :  60
# ### Test solutions :  180
# ###-------------------------------------###
#
#
# ###-------------------------------------###
# ### Solutions files are ready!
# ###-------------------------------------###
#
#
# ======= Set 1 (Style_trans_fair_challenge_train): geometric_mean_accuracy_metric(set1_score)=1.000000000000 =======
# ======= Set 2 (Style_trans_fair_challenge_test): geometric_mean_accuracy_metric(set2_score)=0.000000000000 =======

# %% [markdown]
# # Prepare the submission

# %%
import datetime 
from data_io import zipdir
the_date = datetime.datetime.now().strftime("%y-%m-%d-%H-%M")
sample_code_submission = 'sample_code_submission_' + the_date + '.zip'
# sample_result_submission = 'sample_result_submission_' + the_date + '.zip'
zipdir(sample_code_submission, model_dir)
# zipdir(sample_result_submission, result_dir)
print("Submit this file to codalab:\n" + sample_code_submission)
# Out:
# Submit this file to codalab:
# sample_code_submission_23-01-30-16-11.zip
