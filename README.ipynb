# %%
from IPython.display import Image
Image(filename="images/logo.jpg", width=200)

# %% [markdown]
# <div style="background:#FFFFFF">
# <!-- <img src="../images/dataset-cover.jpg" width=150 ALIGN="left" style='margin-right:10px; border-style: solid; border-width: 2px;' alt='logo'> -->
# <h1>Starting Kit - Style-Trans-Fair </h1>
# <p>
# This starting kit will guide you step by step and will walk you through the data statistics and<br>
# examples. This will give you a clear idea of what this challenge is about and how you can<br>
# proceed further to solve the challenge.
# </p>
#
# <br><br>
# <hr style='background-color: #D3D3D3; height: 1px; border: 0;'>
# <p>
# This code was tested with Python 3.8.5 |Anaconda custom (64-bit)| (default, Dec 23 2020, 21:19:02) (https://anaconda.org/)<br>
# </p>
# <hr style='background-color: #D3D3D3; height: 1px; border: 0;'>
#
# <p>
# ALL INFORMATION, SOFTWARE, DOCUMENTATION, AND DATA ARE PROVIDED "AS-IS". The CHALEARN, AND/OR OTHER ORGANIZERS OR CODE AUTHORS DISCLAIM ANY EXPRESSED OR IMPLIED WARRANTIES, INCLUDING, BUT NOT LIMITED TO, THE IMPLIED WARRANTIES OF MERCHANTABILITY AND FITNESS FOR ANY PARTICULAR PURPOSE, AND THE WARRANTY OF NON-INFRIGEMENT OF ANY THIRD PARTY'S INTELLECTUAL PROPERTY RIGHTS. IN NO EVENT SHALL AUTHORS AND ORGANIZERS BE LIABLE FOR ANY SPECIAL,
# INDIRECT OR CONSEQUENTIAL DAMAGES OR ANY DAMAGES WHATSOEVER ARISING OUT OF OR IN CONNECTION WITH THE USE OR PERFORMANCE OF SOFTWARE, DOCUMENTS, MATERIALS, PUBLICATIONS, OR INFORMATION MADE AVAILABLE FOR THE CHALLENGE.
# </p>
#
# <hr style='background-color: #D3D3D3; height: 1px; border: 0;'>
#     <p>
# This challenge was organized by <b>Team Fairness National Assembly</b> of <b><a style='color:#4D6605;' href='http://www.chalearn.org/'>ChaLearn</a></b>  at <b><a style='color: #62023C;' href='https://www.universite-paris-saclay.fr/'>Université Paris Saclay</a></b>
# </p>
# </div>
#
# <hr style='background-color: #D3D3D3; height: 1px; border: 0;'>

# %% [markdown]
# ***
# # Introduction
#
# This challenge uses a Dataset from ***Meta Album***. There are 5 tasks in the Development phase and 5 tasks in the Final Phase.
# Each task in the dataset consists of **360** images splited into 9 groups:
# <!--
# <p>
# <img src="../images/task_distribution.png">
# </p> -->

# %%
Image(filename="images/task_distribution.png")

# %% [markdown]
# where the training set is biased in Style, and the test set is balanced.
#
# The sample dataset in this starting kit conists of **360** images of the Insect classification task.
#
# This challenge is about creating a Machine Learning model and train it with the data provided to classify the images into the mentioned 3 Classes without being biased towards Styles.
#
#
# **References and credits:**
#  - Meta Album (https://meta-album.github.io/)
#  - Université Paris Saclay (https://www.universite-paris-saclay.fr/)
#  - ChaLearn (http://www.chalearn.org/)
# ***

# %% [markdown]
# ### Install required packages

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: appnope==0.1.2 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: asttokens==2.0.5 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (2.0.5)
# Requirement already satisfied: backcall==0.2.0 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (0.2.0)
# Collecting Bottleneck==1.3.5
#   Using cached Bottleneck-1.3.5-cp38-cp38-macosx_11_0_arm64.whl
# Requirement already satisfied: certifi==2022.12.7 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (2022.12.7)
# Collecting charset-normalizer==3.0.1
#   Using cached charset_normalizer-3.0.1-cp38-cp38-macosx_11_0_arm64.whl (121 kB)
# Collecting cloudpickle==2.0.0
#   Using cached cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: comm==0.1.2 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (0.1.2)
# Collecting contourpy==1.0.5
#   Using cached contourpy-1.0.5-cp38-cp38-macosx_11_0_arm64.whl (225 kB)
# Collecting cycler==0.11.0
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting cytoolz==0.12.0
#   Using cached cytoolz-0.12.0-cp38-cp38-macosx_11_0_arm64.whl (359 kB)
# Collecting dask==2022.7.0
#   Using cached dask-2022.7.0-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: debugpy==1.5.1 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (1.5.1)
# Requirement already satisfied: decorator==5.1.1 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 14)) (5.1.1)
# Requirement already satisfied: entrypoints==0.4 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 15)) (0.4)
# Requirement already satisfied: executing==0.8.3 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 16)) (0.8.3)
# Collecting fonttools==4.25.0
#   Using cached fonttools-4.25.0-py3-none-any.whl (867 kB)
# Collecting fsspec==2022.11.0
#   Using cached fsspec-2022.11.0-py3-none-any.whl (139 kB)
# Collecting idna==3.4
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting imageio==2.19.3
#   Using cached imageio-2.19.3-py3-none-any.whl (3.4 MB)
# Requirement already satisfied: ipykernel==6.19.2 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 21)) (6.19.2)
# Collecting ipython==8.7.0
#   Downloading ipython-8.7.0-py3-none-any.whl (761 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 761.7/761.7 kB 14.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: jedi==0.18.1 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 23)) (0.18.1)
# Collecting joblib==1.1.1
#   Using cached joblib-1.1.1-py2.py3-none-any.whl (309 kB)
# Requirement already satisfied: jupyter_client==7.4.8 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 25)) (7.4.8)
# Requirement already satisfied: jupyter_core==5.1.1 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 26)) (5.1.1)
# Collecting kiwisolver==1.4.4
#   Using cached kiwisolver-1.4.4-cp38-cp38-macosx_11_0_arm64.whl (63 kB)
# Collecting locket==1.0.0
#   Using cached locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Collecting matplotlib==3.6.2
#   Using cached matplotlib-3.6.2-cp38-cp38-macosx_11_0_arm64.whl (7.2 MB)
# Requirement already satisfied: matplotlib-inline==0.1.6 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 30)) (0.1.6)
# Collecting munkres==1.1.4
#   Using cached munkres-1.1.4-py2.py3-none-any.whl (7.0 kB)
# Requirement already satisfied: nest-asyncio==1.5.6 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 32)) (1.5.6)
# Collecting networkx==2.8.4
#   Using cached networkx-2.8.4-py3-none-any.whl (2.0 MB)
# Collecting numexpr==2.8.4
#   Using cached numexpr-2.8.4-cp38-cp38-macosx_11_0_arm64.whl (89 kB)
# Collecting numpy==1.23.5
#   Using cached numpy-1.23.5-cp38-cp38-macosx_11_0_arm64.whl (13.3 MB)
# Collecting opencv-python==4.7.0.68
#   Using cached opencv_python-4.7.0.68-cp37-abi3-macosx_11_0_arm64.whl (31.1 MB)
# Requirement already satisfied: packaging==22.0 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 37)) (22.0)
# Collecting pandas==1.5.2
#   Using cached pandas-1.5.2-cp38-cp38-macosx_11_0_arm64.whl (10.7 MB)
# Requirement already satisfied: parso==0.8.3 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 39)) (0.8.3)
# Collecting partd==1.2.0
#   Using cached partd-1.2.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: pexpect==4.8.0 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 41)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 42)) (0.7.5)
# Collecting Pillow==9.3.0
#   Using cached Pillow-9.3.0-cp38-cp38-macosx_11_0_arm64.whl (2.9 MB)
# Requirement already satisfied: pip==22.3.1 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 44)) (22.3.1)
# Requirement already satisfied: platformdirs==2.5.2 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 45)) (2.5.2)
# Requirement already satisfied: prompt-toolkit==3.0.36 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 46)) (3.0.36)
# Requirement already satisfied: psutil==5.9.0 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 47)) (5.9.0)
# Requirement already satisfied: ptyprocess==0.7.0 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 48)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 49)) (0.2.2)
# Requirement already satisfied: Pygments==2.11.2 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 50)) (2.11.2)
# Collecting pyparsing==3.0.9
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Requirement already satisfied: python-dateutil==2.8.2 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 52)) (2.8.2)
# Collecting pytz==2022.7
#   Using cached pytz-2022.7-py2.py3-none-any.whl (499 kB)
# Collecting PyWavelets==1.4.1
#   Using cached PyWavelets-1.4.1-cp38-cp38-macosx_11_0_arm64.whl (4.3 MB)
# Collecting PyYAML==6.0
#   Using cached PyYAML-6.0-cp38-cp38-macosx_11_0_arm64.whl
# Requirement already satisfied: pyzmq==23.2.0 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 56)) (23.2.0)
# Collecting scikit-image==0.19.3
#   Using cached scikit_image-0.19.3-cp38-cp38-macosx_12_0_arm64.whl (12.4 MB)
# Collecting scikit-learn==1.1.3
#   Using cached scikit_learn-1.1.3-cp38-cp38-macosx_12_0_arm64.whl (7.6 MB)
# Collecting scipy==1.9.3
#   Using cached scipy-1.9.3-cp38-cp38-macosx_12_0_arm64.whl (28.5 MB)
# Collecting seaborn==0.12.2
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Requirement already satisfied: setuptools==65.6.3 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 61)) (65.6.3)
# Requirement already satisfied: six==1.16.0 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 62)) (1.16.0)
# Requirement already satisfied: stack-data==0.2.0 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 63)) (0.2.0)
# Collecting threadpoolctl==2.2.0
#   Using cached threadpoolctl-2.2.0-py3-none-any.whl (12 kB)
# Collecting tifffile==2021.7.2
#   Using cached tifffile-2021.7.2-py3-none-any.whl (169 kB)
# Collecting toolz==0.12.0
#   Using cached toolz-0.12.0-py3-none-any.whl (55 kB)
# Requirement already satisfied: tornado==6.2 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 67)) (6.2)
# Requirement already satisfied: traitlets==5.7.1 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 68)) (5.7.1)
# Collecting urllib3==1.26.14
#   Using cached urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
# Requirement already satisfied: wcwidth==0.2.5 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 70)) (0.2.5)
# Requirement already satisfied: wheel==0.37.1 in /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages (from -r requirements.txt (line 71)) (0.37.1)
# Installing collected packages: pytz, munkres, charset-normalizer, urllib3, toolz, threadpoolctl, PyYAML, pyparsing, Pillow, numpy, networkx, locket, kiwisolver, joblib, idna, fsspec, fonttools, cycler, cloudpickle, tifffile, scipy, PyWavelets, partd, pandas, opencv-python, numexpr, imageio, cytoolz, contourpy, Bottleneck, scikit-learn, scikit-image, matplotlib, ipython, dask, seaborn
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.8.0
#     Uninstalling ipython-8.8.0:
#       Successfully uninstalled ipython-8.8.0
# Successfully installed Bottleneck-1.3.5 Pillow-9.3.0 PyWavelets-1.4.1 PyYAML-6.0 charset-normalizer-3.0.1 cloudpickle-2.0.0 contourpy-1.0.5 cycler-0.11.0 cytoolz-0.12.0 dask-2022.7.0 fonttools-4.25.0 fsspec-2022.11.0 idna-3.4 imageio-2.19.3 ipython-8.7.0 joblib-1.1.1 kiwisolver-1.4.4 locket-1.0.0 matplotlib-3.6.2 munkres-1.1.4 networkx-2.8.4 numexpr-2.8.4 numpy-1.23.5 opencv-python-4.7.0.68 pandas-1.5.2 partd-1.2.0 pyparsing-3.0.9 pytz-2022.7 scikit-image-0.19.3 scikit-learn-1.1.3 scipy-1.9.3 seaborn-0.12.2 threadpoolctl-2.2.0 tifffile-2021.7.2 toolz-0.12.0 urllib3-1.26.14

# %% [markdown]
# ### Imports

# %%
# import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Image
from PIL import Image
from sklearn.decomposition import PCA
import os

# %%
model_dir = 'sample_code_submission/' # Change the model to a better one once you have one!
result_dir = 'sample_result_submission/' 
problem_dir = 'ingestion_program/'  
score_dir = 'scoring_program/'
from sys import path; path.append(model_dir); path.append(problem_dir); path.append(score_dir); 
# %matplotlib inline
# Uncomment the next lines to auto-reload libraries (this causes some problem with pickles in Python 3)
# %load_ext autoreload
# %autoreload 2
import seaborn as sns; sns.set()
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# %reload_ext autoreload

# %% [markdown]
# ***
# # Step 1: Exploratory data analysis
# We provide `sample_data` with the starting kit, but to prepare your submission, you must fetch the `public_data` from the challenge website and point to it.
#
# The data used for this challenge has images resized into 512x512 pixels.

# %%
data_name = 'style_trans_fair_challenge' # DO NOT CHANGE
data_dir = 'sample_data' # Change it to point to the directory with public_data
image_dir = os.path.join(data_dir, 'stylized')

# %% [markdown]
# ### Load Data

# %%
from data_io import read_data
data, meta_data = read_data(os.path.join(data_dir, 'task1'), random_state=42)
# Out:
# ###-------------------------------------###
# ### Checking Data
# ###-------------------------------------###
#
#
# -------------------------------------
# [+] Your dataset is in perfect format
# -------------------------------------
#
#
# ###-------------------------------------###
# ### Loading Data
# ###-------------------------------------###
#
#
# -------------------------------------
# [+] Data loaded successfully
# -------------------------------------
#
#
# ###-------------------------------------###
# ### Loading Images
# ###-------------------------------------###
#
#
# -------------------------------------
# [+] Images loaded successfully
# -------------------------------------

# %% [markdown]
# ### Data Statistics

# %%
print("Categories/Classes : ", np.unique(data['train_labels']))
print("Styles : ", np.unique(data['train_styles']))
print("Train Images:", len(data['train_images']))
print("Test Images:", len(data['test_images']))
# Out:
# Categories/Classes :  ['Apoidea' 'Elateroidea' 'Tenthredinoidea']
# Styles :  ['autumn_leaves' 'number_one' 'trippy_flowers']
# Train Images: 60
# Test Images: 180

# %% [markdown]
# ## Visualization

# %%
def print_style_transfer_samples(row):
    f, ax = plt.subplots(1, 3)
    f.set_figheight(5)
    f.set_figwidth(15)
    ax[0].imshow(Image.open(os.path.join(data_dir, 'task1', 'content', row['ORIG_CATEGORY_FILE'].iloc[0])))
    ax[0].set_title('Original')
    ax[0].set_axis_off()
    ax[1].imshow(Image.open(os.path.join(data_dir, 'task1', 'styles', row['ORIG_STYLE_FILE'].iloc[0])))
    ax[1].set_title('Style')
    ax[1].set_axis_off()
    ax[2].imshow(Image.open(os.path.join(data_dir, 'task1', 'stylized', row['FILE_NAME'].iloc[0])))
    ax[2].set_title('Stylized')
    ax[2].set_axis_off()

# %%
print_style_transfer_samples(data['train_df'].sample(1))

# %% [markdown]
# ### Distribution of Classes/Labels

# %% [markdown]
# #### Train

# %%
grouped = data['train_df'].groupby(["CATEGORY", "STYLE"]).size().reset_index(name="COUNT")
grouped
# Out:
#           CATEGORY           STYLE  COUNT
# 0          Apoidea   autumn_leaves     12
# 1          Apoidea      number_one      4
# 2          Apoidea  trippy_flowers      4
# 3      Elateroidea   autumn_leaves      4
# 4      Elateroidea      number_one     12
# 5      Elateroidea  trippy_flowers      4
# 6  Tenthredinoidea   autumn_leaves      4
# 7  Tenthredinoidea      number_one      4
# 8  Tenthredinoidea  trippy_flowers     12

# %%
# Create the heatmap visualization for category and style
sns.heatmap(grouped.pivot("CATEGORY", "STYLE", "COUNT"), cmap="crest", annot=True, linewidths=1, linecolor='black')
plt.title('Heatmap visualization for category and style')
plt.xticks(rotation=45)
# Show the plot
plt.show()

# %% [markdown]
# #### Test

# %%
grouped = data['test_df'].groupby(["CATEGORY", "STYLE"]).size().reset_index(name="COUNT")
grouped
# Out:
#           CATEGORY           STYLE  COUNT
# 0          Apoidea   autumn_leaves     20
# 1          Apoidea      number_one     20
# 2          Apoidea  trippy_flowers     20
# 3      Elateroidea   autumn_leaves     20
# 4      Elateroidea      number_one     20
# 5      Elateroidea  trippy_flowers     20
# 6  Tenthredinoidea   autumn_leaves     20
# 7  Tenthredinoidea      number_one     20
# 8  Tenthredinoidea  trippy_flowers     20

# %%
# Create the heatmap visualization for category and style
sns.heatmap(grouped.pivot("CATEGORY", "STYLE", "COUNT"), cmap="crest", annot=True, linewidths=1, linecolor='black')
plt.title('Heatmap visualization for category and style')
plt.xticks(rotation=45)
# Show the plot
plt.show()

# %% [markdown]
# ### Further visualization

# %% [markdown]
# For further exploratory data analysis, we analyze the RGB color model and plot the graph. We get the mean for each channel of each image, and save it in the columns of a dataframe.

# %%
rgb = pd.DataFrame(
    np.zeros((len(data['train_df']), 5)), columns=list("RGB") + ["category", "style"]
)
for i in range(len(data['train_labels'])):
    img = data['train_images'][i]
    rgb.iloc[i, :3] = img.mean(axis=(0,1))
    rgb.iloc[i, 3] = data['train_labels'][i]
    rgb.iloc[i, 4] = data['train_styles'][i]
rgb.head()
# Out:
#             R           G           B category          style
# 0  185.463245  123.971504   90.363346  Apoidea  autumn_leaves
# 1  198.921322  140.519951  100.389927  Apoidea  autumn_leaves
# 2  161.680676  107.409931   34.452591  Apoidea  autumn_leaves
# 3  178.205879   99.362656   25.734722  Apoidea  autumn_leaves
# 4  215.121761   89.867352   39.462254  Apoidea  autumn_leaves

# %% [markdown]
# We also normalize each color vector, so that we only care about the direction of the color vector and not about its magnitude.

# %%
pca = PCA(2)
rgb[list("rgb")] = rgb[list("RGB")] / np.sqrt(
    np.sum(np.square(rgb[list("RGB")]), axis=1).values.reshape(-1, 1)
) 

transformed_rgb = pca.fit_transform(rgb[list("rgb")]) 
rgb[list("xy")] = transformed_rgb 
red, green, blue = pca.transform(np.identity(3))
# Out:
# /Users/ktgiahieu/miniconda3/envs/test_env/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(

# %%
plot_data = rgb
plt.figure(figsize=(10, 10))
sns.scatterplot(x="x", y="y", hue="category", data=plot_data, palette="Set1")
plt.arrow(0, 0, *blue, color="blue")
plt.arrow(0, 0, *green, color="green")
plt.arrow(0, 0, *red, color="red")
plt.title("RGB distribution")
plt.xlabel("First PC")
plt.ylabel("Second PC")
plt.legend()
plt.show()

# %% [markdown]
# Next, we analyze the brightness of the images per category. We wanted to know which category has lower/higher brightness level so instead of using a simple mean for each RGB channel, we used a weighted mean that takes into account the perceived brightness by humans:
# - Red: 21.26%
# - Green: 71.52%
# - Blue: 7.22%

# %%
BRIGHTNESS_VECTOR = np.array([0.2126, 0.7152, 0.0722])
rgb["brightness"] = (
    rgb[list("RGB")] @ BRIGHTNESS_VECTOR / 255
)
rgb.head()
# Out:
#             R           G           B category          style         r  \
# 0  185.463245  123.971504   90.363346  Apoidea  autumn_leaves  0.770552
# 1  198.921322  140.519951  100.389927  Apoidea  autumn_leaves  0.755129
# 2  161.680676  107.409931   34.452591  Apoidea  autumn_leaves  0.820128
# 3  178.205879   99.362656   25.734722  Apoidea  autumn_leaves  0.866543
# 4  215.121761   89.867352   39.462254  Apoidea  autumn_leaves  0.909780
#
#           g         b         x         y  brightness
# 0  0.515070  0.375436  0.059124  0.001582    0.527914
# 1  0.533431  0.381092  0.042863 -0.016888    0.588387
# 2  0.544839  0.174761  0.246337 -0.088686    0.445805
# 3  0.483160  0.125138  0.323796 -0.040875    0.434544
# 4  0.380062  0.166891  0.331460  0.078218    0.442577

# %% [markdown]
# Using the boxplot we could easily identify the minimum, maximum, interquartile range, median and the outliers. Here we ordered it in respect to their lower quartile (Q1) to make it more representative.

# %%
plot_data = rgb[["category", "brightness"]].copy()
order = plot_data.groupby("category")["brightness"].quantile(0.25).sort_values().index.tolist()
plt.figure(figsize=(8, 8))
sns.boxplot(y="category", x="brightness", data=plot_data, order=order, palette="Set1")
plt.title("Luminance (perceived brightness)") 
plt.show()

# %%
ax = pd.DataFrame(rgb.groupby("category")["brightness"].mean()).plot.barh()
plt.xlabel("Brightness level")
plt.title("Plot of the brightness level")
plt.show()

# %% [markdown]
# From the graph above we can conclude that the category Elateroidea has the highest value in term of brightness level

# %% [markdown]
# ***
# # Step 2: Building a predictive model

# %% [markdown]
# ## Training a predictive model
# We provide an example of predictive model in the `sample_code_submission/` directory.
# The model will perform the following steps:
# - Resize the image to (64,64,3)
# - Flatten the image to a vector of size 64\*64\*3 = 12288
# - Train a simple Support Vector Machine to classify
#
# You should change this model and use a better one to get a good score for the challenge

# %%
from data_io import write
from model import model

# %% [markdown]
# <div style="background:#FFF">
# an instance of the model (run the constructor) and attempt to reload a previously saved version from `sample_code_submission/`:
# </div>

# %%
myModel = model()
trained_model_name = model_dir + data_name
# Uncomment the next line to re-load an already trained model
#myModel = myModel.load(trained_model_name)

# %% [markdown]
# <div style="background:#FFF">
#     Train the model (unless you reloaded a trained model) and make predictions.
# </div>

# %%
X_TRAIN = data["train_images"]
STYLE_TRAIN = data["train_styles"]
Y_TRAIN = data["train_labels_num"]
X_TEST = data["test_images"]
STYLE_TEST = data["test_styles"]
Y_TEST = data["test_labels_num"]

# %%
if not(myModel.is_trained):
    myModel.fit(X_TRAIN, Y_TRAIN)                     

Y_hat_train = myModel.predict(X_TRAIN) # Optional, not really needed to test on taining examples
Y_hat_test = myModel.predict(X_TEST)
# Out:
# FIT: dim(X)= [60, 12288]
# FIT: dim(y)= [60, 1]
# PREDICT: dim(X)= [60, 12288]
# PREDICT: dim(y)= [60, 1]
# PREDICT: dim(X)= [180, 12288]
# PREDICT: dim(y)= [180, 1]

# %% [markdown]
# **Save the trained model** (will be ready to reload next time around) and save the prediction results. <br>

# %%
myModel.save(trained_model_name)

# %% [markdown]
# **IMPORTANT:** if you save the trained model, it will be bundled with your sample code submission. Therefore your model will NOT be retrained on the challenge platform. Remove the pickle from the submission if you want the model to be retrained on the platform.
#
# **REQUIRED:** Trained model is required in the submission to codabench.

# %%
result_name = result_dir + data_name
from data_io import write
write(result_name + '_train.predict', Y_hat_train)
write(result_name + '_test.predict', Y_hat_test)

# !ls $result_name*
# Out:
# sample_result_submission/style_trans_fair_challenge_test.predict
# sample_result_submission/style_trans_fair_challenge_train.predict

# %% [markdown]
# ## Scoring the results
# ### Load the challenge metric
#
# **The metric chosen for your challenge** is identified in the "metric.txt" file found in the `scoring_program/` directory.
# <br>
# The function "get_metric" searches first for a metric having that name in my_metric.py, then in libscores.py, then in sklearn.metric.
#
# Currently, we are using geometric_mean_accuracy_metric, which is calculated by:
# - Split the data in 9 groups, where images in each group have the same style and category
# - Calculate the accuracy in each group
# - Calculate the Geometric Mean of those 9 accuracies

# %%
from libscores import get_metric
metric_name, scoring_function = get_metric()
print('Using scoring metric:', metric_name)
# Uncomment the next line to display the code of the scoring metric
#??scoring_function
# Out:
# Using scoring metric: geometric_mean_accuracy_metric

# %% [markdown]
# ## Training performance

# %%
print('Training score for the', metric_name, 'metric = %5.4f' % scoring_function(Y_TRAIN, Y_hat_train, STYLE_TRAIN))
print('Ideal score for the', metric_name, 'metric = %5.4f' % scoring_function(Y_TRAIN, Y_TRAIN, STYLE_TRAIN))

print('Test score for the', metric_name, 'metric = %5.4f' % scoring_function(Y_TEST, Y_hat_test, STYLE_TEST))
# Out:
# Training score for the geometric_mean_accuracy_metric metric = 1.0000
# Ideal score for the geometric_mean_accuracy_metric metric = 1.0000
# Test score for the geometric_mean_accuracy_metric metric = 0.0000

# %% [markdown]
# You can add here other scores and result visualization.

# %% [markdown]
# ## Confusion matrix

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix = confusion_matrix(Y_TRAIN, Y_hat_train)

# %%
confusion_matrix
# Out:
# array([[20,  0,  0],
#        [ 0, 20,  0],
#        [ 0,  0, 20]])

# %%
df_cm = pd.DataFrame(confusion_matrix, range(confusion_matrix.shape[0]), range(confusion_matrix.shape[1]))
sns.heatmap(df_cm, annot=True)
plt.title("Train - Confustion Matrix")
plt.show()

# %% [markdown]
# ***
# # Step 3: Making a submission
#
# ## Unit testing
#
# It is <b><span style="color:red">important that you test your submission files before submitting them</span></b>. All you have to do to make a submission is modify the file <code>model.py</code> in the <code>sample_code_submission/</code> directory, then run this test to make sure everything works fine. This is the actual program that will be run on the server to test your submission.
# <br>
# Keep the sample code simple.<br>
#
# <code>python3</code> is required for this step

# %%
# !source activate python3; 
# !python3 $problem_dir/ingestion.py $data_dir $result_dir $problem_dir $model_dir
# Out:
# Using input_dir: /Users/ktgiahieu/Documents/style-trans-fair/sample_data
# Using output_dir: /Users/ktgiahieu/Documents/style-trans-fair/sample_result_submission
# Using program_dir: /Users/ktgiahieu/Documents/style-trans-fair/ingestion_program
# Using submission_dir: /Users/ktgiahieu/Documents/style-trans-fair/sample_code_submission
# Data name: style_trans_fair_challenge
#
# ========== Ingestion program version 6 ==========
#
# ************************************************
# ******** Processing dataset Style_trans_fair_challenge ********
# ************************************************
# ========= Reading and converting data ==========
# /Users/ktgiahieu/Documents/style-trans-fair/sample_data
# ###-------------------------------------###
# ### Checking Data
# ###-------------------------------------###
#
#
# -------------------------------------
# [+] Your dataset is in perfect format
# -------------------------------------
#
#
# ###-------------------------------------###
# ### Loading Data
# ###-------------------------------------###
#
#
# -------------------------------------
# [+] Data loaded successfully
# -------------------------------------
#
#
# ###-------------------------------------###
# ### Loading Images
# ###-------------------------------------###
#
#
# -------------------------------------
# [+] Images loaded successfully
# -------------------------------------
#
#
# [+] Cumulated time budget (all tasks so far)  500.00 sec
# [+] Time budget for this task 500.00 sec
# [+] Remaining time after reading data 497.48 sec
# ======== Creating model ==========
# **********************************************************
# ****** Attempting to reload model to avoid training ******
# **********************************************************
# Model reloaded from: /Users/ktgiahieu/Documents/style-trans-fair/sample_code_submission/style_trans_fair_challenge_model.pickle
# [+] Model reloaded, no need to train!
# PREDICT: dim(X)= [60, 12288]
# PREDICT: dim(y)= [60, 1]
# PREDICT: dim(X)= [180, 12288]
# PREDICT: dim(y)= [180, 1]
# [+] Prediction success, time spent so far 15.79 sec
# ======== Saving results to: /Users/ktgiahieu/Documents/style-trans-fair/sample_result_submission
# [+] Results saved, time spent so far 15.80 sec
# [+] End cycle, time left 484.20 sec
# [+] Done
# [+] Overall time spent 18.58 sec ::  Overall time budget 500.00 sec

# %% [markdown]
# ### Test scoring program

# %%
scoring_output_dir = 'scoring_output'
# !source activate deeplearning; 
# !python3 $score_dir/score.py $data_dir $result_dir $scoring_output_dir
# Out:
# ###-------------------------------------###
# ### Using metric :  geometric_mean_accuracy_metric
# ###-------------------------------------###
#
#
# ###-------------------------------------###
# ### Train solutions :  60
# ### Test solutions :  180
# ###-------------------------------------###
#
#
# ###-------------------------------------###
# ### Solutions files are ready!
# ###-------------------------------------###
#
#
# ======= Set 1 (Style_trans_fair_challenge_train): geometric_mean_accuracy_metric(set1_score)=1.000000000000 =======
# ======= Set 2 (Style_trans_fair_challenge_test): geometric_mean_accuracy_metric(set2_score)=0.000000000000 =======

# %% [markdown]
# # Prepare the submission

# %%
import datetime 
from data_io import zipdir
the_date = datetime.datetime.now().strftime("%y-%m-%d-%H-%M")
sample_code_submission = 'sample_code_submission_' + the_date + '.zip'
# sample_result_submission = 'sample_result_submission_' + the_date + '.zip'
zipdir(sample_code_submission, model_dir)
# zipdir(sample_result_submission, result_dir)
print("Submit this file to codalab:\n" + sample_code_submission)
# Out:
# Submit this file to codalab:
# sample_code_submission_23-01-28-14-42.zip
